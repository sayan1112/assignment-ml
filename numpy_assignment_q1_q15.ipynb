# %%
import numpy as np
print(np.__version__)

# %%
# Q1 data cell
s1 = [72, 85, 60, 91]
s2 = [45, 30, 98, 55]
s3 = [88, 66, 74, 100]
old = np.array([['62', '71', '55', '80'],
                ['49', '58', '66', '73']])

# %%
# Q1 answers
table = np.array([s1, s2, s3]); print(table)
print(table.shape[0], table.shape[1])
print(table.size)
print(table.astype(float))
old_num = old.astype(int); print(old_num.sum(axis=1))
print(np.vstack((table, old_num)))

# %%
# Q2 data cell
# No predefined arrays for this question.

# %%
# Q2 answers
blank = np.zeros((6, 4), dtype=int); print(blank)
temp = np.full((6, 4), 35); print(temp)
rolls = np.arange(101, 131, 2); print(rolls); print(rolls.size)
time_marks = np.linspace(0, 3, 7); print(time_marks)
diag10 = np.eye(5, dtype=int) * 10; print(diag10)
diag100_else35 = np.full((4, 4), 35, dtype=int) + np.eye(4, dtype=int) * 65; print(diag100_else35)

# %%
# Q3 data cell
present = np.array([22, 18, 25, 12, 20, 24, 9, 21, 17, 23])

# %%
# Q3 answers
print(present[0], present[-1])
print(present[1::2])
print(present[-4:])
print(present[::-1][::3])
present_mid = present.copy(); present_mid[len(present)//2 - 1:len(present)//2 + 1] = 30; print(present_mid)
print(present[:len(present)//2] - present[len(present)//2:])
print(present[::-1][:3])

# %%
# Q4 data cell
marks = np.array([[72, 85, 60, 91],
                  [45, 30, 98, 55],
                  [88, 66, 74, 100],
                  [95, 92, 55, 40],
                  [30, 48, 62, 70]])

# %%
# Q4 answers
print(marks[1:4, 1:3])
print(marks[:, -1])
print(marks[:, [0, -1]])
print(marks[::-1])
marks_chem = marks.copy(); marks_chem[:, 2] += 5; print(marks_chem)
print(marks[-1, -2])
print(marks[-2:, :2])

# %%
# Q5 data cell
totals = np.array([245, 310, 178, 392, 140, 265, 199, 155, 288, 132])

# %%
# Q5 answers
print(totals[totals > 250])
band = totals[(totals > 180) & (totals < 250)]; print(band)
print(totals[(totals < 150) | (totals > 380)])
print(band.size)
print(totals[totals > 200].mean())
print(np.where(totals < 150)[0])
print(totals[totals <= 250].max())

# %%
# Q6 data cell
marks = np.array([40, 55, 62, 88, 95, 33, 71, 58])

# %%
# Q6 answers
inc = np.round(marks * 1.15, 2); print(inc)
capped = np.clip(inc, None, 100); print(capped)
print(np.sum((inc - marks) < 10))
print(np.sum(marks < 40), np.sum(capped < 40))
print(np.round(marks / marks.max() * 100, 1))
print(np.round((inc - marks).sum(), 2))

# %%
# Q7 data cell
marks = np.array([72, 45, 88, 95, 30, 67, 91, 54, 78, 39])

# %%
# Q7 answers
avg = marks.mean(); med = np.median(marks); print(avg, med)
print(marks.max() - marks.min())
print(np.argmax(marks), np.argmin(marks))
print(np.partition(marks, -2)[-2])
print(np.sum(marks > avg))
std = marks.std(); print(np.sum((marks >= avg - std) & (marks <= avg + std)))
print(np.round(marks[marks != marks.max()].mean(), 2))

# %%
# Q8 data cell
marks = np.array([[72, 85, 60, 91],
                  [45, 30, 98, 55],
                  [88, 66, 74, 100],
                  [95, 92, 55, 40],
                  [30, 48, 62, 70]])

# %%
# Q8 answers
sub_avg = marks.mean(axis=0); stu_tot = marks.sum(axis=1); print(sub_avg); print(stu_tot)
print(np.argmin(sub_avg))
print(np.argmax(stu_tot))
print(marks.max(axis=0))
print(np.sum(marks > 60, axis=0))
print(np.argmax(np.ptp(marks, axis=0)))
print(stu_tot[np.argmin(marks[:, 2])])

# %%
# Q9 data cell
participants = np.array([101, 102, 103, 104, 105, 106, 107, 108, 109, 110])

# %%
# Q9 answers
np.random.seed(42); winners = np.random.choice(participants, 3); print(winners)
np.random.seed(42); attendance_pct = np.random.randint(60, 101, 10); print(attendance_pct)
np.random.seed(42); rand_marks = np.round(np.random.rand(4, 3) * 100).astype(int); print(rand_marks)
np.random.seed(42); shuffled = participants.copy(); np.random.shuffle(shuffled); print(shuffled[:4])
np.random.seed(42); dice = np.random.randint(1, 7, 20); print(np.sum(dice == 6))
print(participants[attendance_pct > 80])

# %%
# Q10 data cell
marks = np.array([[72, 85, 60, 91],
                  [45, 30, 98, 55],
                  [88, 66, 74, 100],
                  [95, 92, 55, 40]])

grace     = np.array([5, 0, 8, 3])
weightage = np.array([1.2, 1.0, 1.1, 1.0])

# %%
# Q10 answers
grace_applied = np.minimum(marks + grace, 100); print(grace_applied)
weighted = np.round(marks * weightage, 1); print(weighted)
dev = marks - marks.mean(axis=0); print(dev)
bonus = np.array([5, 0, 2, 0]).reshape(-1, 1); print(marks + bonus)
print(np.sum(dev < 0))
scaled = np.round((marks - marks.mean(axis=0)) / marks.std(axis=0), 2); print(scaled)

# %%
# Q11 data cell
metres   = np.array([200, 500, 900, 100, 700])
sanskrit = np.array([65, 70, 88, 92, 54])

# %%
# Q11 answers
D = np.abs(metres[:, np.newaxis] - metres[np.newaxis, :]); print(D)
print(D.max(axis=1))
print(np.argmin(D[0, 1:]) + 1)
upper = np.triu(D, 1); r, c = np.where(upper == upper[upper > 0].min()); print(np.column_stack((r, c)))
print(np.arange(1, 25).reshape(-1, 6))
print(sanskrit.reshape(-1, 1)); print(sanskrit[:, np.newaxis])
print(sanskrit.reshape(1, -1))

# %%
# Q12 data cell
master = np.array([[10, 20, 30],
                   [40, 50, 60],
                   [70, 80, 90]])

# %%
# Q12 answers
flat_copy = master.flatten(); flat_copy[0] = 999; print(master)
master_view = master.copy(); flat_view = master_view.ravel(); flat_view[-1] = 111; print(master_view)
middle_zero = master.copy(); middle_zero[1, :] = 0; print(middle_zero)
double_copy = master.copy(); double_copy[:, :2] *= 2; print(double_copy)
inplace_master = master.copy(); inplace_master[:, :2] *= 2; print(inplace_master)
reduced = np.where(master > 50, master - 10, master); print(reduced)

# %%
# Q13 data cell
sec_A = np.array([[72, 85, 60],
                  [45, 30, 98],
                  [88, 66, 74]])

sec_B = np.array([[95, 92, 55],
                  [30, 48, 62]])

roll_C  = np.array([201, 202, 203, 204])
marks_C = np.array([67, 82, 45, 91])

# %%
# Q13 answers
combined = np.vstack((sec_A, sec_B)); print(combined.shape)
combined_tot = np.hstack((combined, combined.sum(axis=1, keepdims=True))); print(combined_tot)
table_c = np.column_stack((roll_C, marks_C)); print(table_c)
print(np.vstack((table_c, np.array([205, 73]))))
serial = np.arange(1, combined.shape[0] + 1).reshape(-1, 1); print(np.hstack((serial, combined)))
print(combined[combined.sum(axis=1) > 200])
grades = np.where(combined.sum(axis=1) >= 225, 'A', np.where(combined.sum(axis=1) >= 150, 'B', 'C')); print(np.column_stack((combined.astype(str), grades)))

# %%
# Q14 data cell
marks = np.array([[70, 65, 80],
                  [55, 90, 32],
                  [88, 76, 91],
                  [40, 52, 45],
                  [60, 58, 66]])

attendance = np.array([88, -1, 105, 76, 45, -1, 92, 120, 67, 30])

# %%
# Q14 answers
genuine = attendance[(attendance != -1) & (attendance <= 100)]; repaired = np.where(attendance == -1, genuine.mean(), attendance)
repaired = np.where(repaired > 100, 100, repaired).astype(float); print(repaired)
labels = np.where(repaired >= 85, 'Regular', np.where(repaired >= 60, 'Average', 'Short')); print(labels)
short_idx = np.where(labels == 'Short')[0]; print(short_idx, repaired[short_idx])
rows, cols = np.where(marks < 50); print('rows:', rows); print('cols:', cols)
print(marks[rows, cols])
marks_fixed = np.where(marks < 35, 35, marks); print(marks_fixed); print(np.sum(marks < 35))
print(np.argmax(np.sum(marks < 60, axis=1)))

# %%
# Q15 data cell
M = np.array([[70, 65, 80],
              [55, 90, 72],
              [88, 76, 91],
              [60, 58, 66]])

w = np.array([0.3, 0.3, 0.4])

W = np.array([[0.3, 0.5],
              [0.3, 0.2],
              [0.4, 0.3]])

# %%
# Q15 answers
final_scores = M @ w; print(final_scores)
print(np.argmax(final_scores))
print(np.ones(M.shape[0]) @ M)
both_schemes = np.round(M @ W, 1); print(both_schemes)
print(np.sum(both_schemes[:, 1] > both_schemes[:, 0]))
diff = np.round(both_schemes[:, 1] - both_schemes[:, 0], 2); print(diff)
better = np.max(both_schemes, axis=1, keepdims=True); print(np.hstack((M, better)))
